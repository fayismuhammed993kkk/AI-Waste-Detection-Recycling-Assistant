# %%
import torch

print("PyTorch Version:", torch.__version__)
print("CUDA Available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch Version: 2.11.0+cu128
# CUDA Available: True
# GPU: Tesla T4

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 48.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

dataset_path = "/content/drive/MyDrive/Waste_Detection_Project/Dataset"

print("Dataset exists:", os.path.exists(dataset_path))
print(os.listdir(dataset_path))
# Out:
# Dataset exists: True
# ['README.dataset.txt', 'README.roboflow.txt', 'data.yaml', 'valid', 'test', 'train']

# %%
# !cp -r "/content/drive/MyDrive/Waste_Detection_Project/Dataset" /content/

# %%
model = YOLO("/content/drive/MyDrive/Waste_Detection_Project/Models/waste_detection")

results = model.train(
    data="/content/Dataset/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    workers=2,
    device=0,
    project="/content/drive/MyDrive/Waste_Detection_Project/Models",
    name="waste_detection_50",
    resume=False
)
# Out:
# Ultralytics 8.4.112 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !cp -r "/content/drive/MyDrive/Waste_Detection_Project/Dataset" /content/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 34.7 MB/s eta 0:00:00
# ...

# %%
import torch

print("CUDA Available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA Available: True
# GPU: Tesla T4

# %%
from ultralytics import YOLO

# Load pretrained YOLO11n model
model = YOLO("yolo11n.pt")

# Train on ORIGINAL 42-class dataset
results = model.train(
    data="/content/Dataset/data.yaml",
    epochs=30,
    imgsz=640,
    batch=16,
    workers=2,
    device=0,
    project="/content/drive/MyDrive/Waste_Detection_Project/Models",
    name="waste_detection_yolo11n_42class",
    pretrained=True,
    optimizer="auto",
    cache="disk",
    patience=15,
    plots=True,
    save=True,
    verbose=True,
    seed=42
)
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !unzip -q "/content/drive/MyDrive/Waste_Detection_Project/Dataset_optimized.zip" -d /content/

# %%
import os

print(os.path.exists("/content/Dataset_optimized/data.yaml"))
# !ls /content/Dataset_optimized
# Out:
# True
# data.yaml  test  train	valid

# %%
from ultralytics import YOLO

# Load pretrained YOLOv8n model
model = YOLO("yolov8n.pt")

# Train the model
results = model.train(
    data="/content/Dataset_optimized/data.yaml",
    epochs=30,
    imgsz=640,
    batch=16,
    workers=2,
    device=0,
    project="/content/drive/MyDrive/Waste_Detection_Project/Models",
    name="waste_detection_v8n_optimized",
    pretrained=True,
    optimizer="auto",
    cache=True,
    patience=15,
    plots=True,
    save=True,
    verbose=True,
    seed=42
)
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

# Load pretrained YOLO11n model
model = YOLO("yolo11n.pt")

# Train the model
results = model.train(
    data="/content/Dataset_optimized/data.yaml",
    epochs=30,
    imgsz=640,
    batch=16,
    workers=2,
    device=0,
    project="/content/drive/MyDrive/Waste_Detection_Project/Models",
    name="waste_detection_yolo11n_optimized",
    pretrained=True,
    optimizer="auto",
    cache="disk",
    patience=15,
    plots=True,
    save=True,
    verbose=True,
    seed=42
)
# Out:
# ...
# Ultralytics 8.4.115 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
